# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivabairy005/Deep-Learning-Lab/blob/main/DL_week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# kernel (5,5) strides (2,2)

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(5,5), strides=(2,2), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))


# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - accuracy: 0.8624 - loss: 0.4967 - val_accuracy: 0.9731 - val_loss: 0.0903
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9757 - loss: 0.0848 - val_accuracy: 0.9837 - val_loss: 0.0566
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.9837 - loss: 0.0536 - val_accuracy: 0.9825 - val_loss: 0.0545
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9876 - loss: 0.0399 - val_accuracy: 0.9836 - val_loss: 0.0503
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9903 - loss: 0.0306 - val_accuracy: 0.9843 - val_loss: 0.0496
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9940 - loss: 0.0209 - val_accuracy: 0.9852 - val_loss: 0.0484
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.9954 - loss: 0.0155 - val_accuracy: 0.9853 - val_loss: 0.0445
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9965 - loss: 0.0120 - val_accuracy: 0.9875 - val_loss: 0.0447
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9973 - loss: 0.0093 - val_accuracy: 0.9862 - val_loss: 0.0476
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9865 - val_loss: 0.0490
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9832 - loss: 0.0575
# Test loss: 0.04898180067539215
# Test accuracy: 0.9865000247955322
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Accuracy on test set: 0.9865
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9832 - loss: 0.0575
# loss= 0.04898180067539215
# accuracy= 0.9865000247955322

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(5,5), strides=(1,1), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 54s 111ms/step - accuracy: 0.8903 - loss: 0.3657 - val_accuracy: 0.9792 - val_loss: 0.0653
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 51s 108ms/step - accuracy: 0.9835 - loss: 0.0546 - val_accuracy: 0.9849 - val_loss: 0.0459
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.9898 - loss: 0.0317 - val_accuracy: 0.9843 - val_loss: 0.0488
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 78s 109ms/step - accuracy: 0.9928 - loss: 0.0230 - val_accuracy: 0.9872 - val_loss: 0.0414
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 85s 116ms/step - accuracy: 0.9957 - loss: 0.0140 - val_accuracy: 0.9861 - val_loss: 0.0439
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.9973 - loss: 0.0097 - val_accuracy: 0.9859 - val_loss: 0.0489
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 81s 115ms/step - accuracy: 0.9976 - loss: 0.0079 - val_accuracy: 0.9875 - val_loss: 0.0453
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 0.9886 - val_loss: 0.0443
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 112ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9874 - val_loss: 0.0517
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 54s 116ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9864 - val_loss: 0.0528
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9827 - loss: 0.0663
# Test loss: 0.05283172428607941
# Test accuracy: 0.9864000082015991
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# Accuracy on test set: 0.9864
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9827 - loss: 0.0663
# loss= 0.05283172428607941
# accuracy= 0.9864000082015991

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(5,5), strides=(3,3), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8370 - loss: 0.6113 - val_accuracy: 0.9585 - val_loss: 0.1425
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9620 - loss: 0.1299 - val_accuracy: 0.9748 - val_loss: 0.0887
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9742 - loss: 0.0883 - val_accuracy: 0.9786 - val_loss: 0.0716
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9822 - loss: 0.0596 - val_accuracy: 0.9816 - val_loss: 0.0595
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9858 - loss: 0.0468 - val_accuracy: 0.9831 - val_loss: 0.0558
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9889 - loss: 0.0381 - val_accuracy: 0.9842 - val_loss: 0.0507
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9905 - loss: 0.0306 - val_accuracy: 0.9836 - val_loss: 0.0518
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9919 - loss: 0.0256 - val_accuracy: 0.9832 - val_loss: 0.0542
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9945 - loss: 0.0198 - val_accuracy: 0.9848 - val_loss: 0.0491
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9954 - loss: 0.0164 - val_accuracy: 0.9855 - val_loss: 0.0497
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0583
# Test loss: 0.04970915615558624
# Test accuracy: 0.9854999780654907
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Accuracy on test set: 0.9855
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9819 - loss: 0.0583
# loss= 0.04970915615558624
# accuracy= 0.9854999780654907

# %% [markdown]
# kernel (2,2) strides (2,2)

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(2,2), strides=(2,2), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 0.8476 - loss: 0.5990 - val_accuracy: 0.9494 - val_loss: 0.1735
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9554 - loss: 0.1554 - val_accuracy: 0.9684 - val_loss: 0.1063
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9718 - loss: 0.0949 - val_accuracy: 0.9732 - val_loss: 0.0890
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.9799 - loss: 0.0667 - val_accuracy: 0.9744 - val_loss: 0.0801
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - accuracy: 0.9858 - loss: 0.0496 - val_accuracy: 0.9764 - val_loss: 0.0768
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 26s 44ms/step - accuracy: 0.9883 - loss: 0.0396 - val_accuracy: 0.9750 - val_loss: 0.0745
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.9925 - loss: 0.0275 - val_accuracy: 0.9759 - val_loss: 0.0796
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9940 - loss: 0.0231 - val_accuracy: 0.9770 - val_loss: 0.0720
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.9956 - loss: 0.0163 - val_accuracy: 0.9779 - val_loss: 0.0782
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.9967 - loss: 0.0133 - val_accuracy: 0.9785 - val_loss: 0.0734
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9759 - loss: 0.0822
# Test loss: 0.07343564182519913
# Test accuracy: 0.9785000085830688
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Accuracy on test set: 0.9785
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9759 - loss: 0.0822
# loss= 0.07343564182519913
# accuracy= 0.9785000085830688

# %% [markdown]
# kernel (3,3) strides (1,1)

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 57s 119ms/step - accuracy: 0.8885 - loss: 0.3795 - val_accuracy: 0.9777 - val_loss: 0.0720
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.9809 - loss: 0.0640 - val_accuracy: 0.9818 - val_loss: 0.0566
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 126ms/step - accuracy: 0.9895 - loss: 0.0360 - val_accuracy: 0.9834 - val_loss: 0.0493
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 56s 120ms/step - accuracy: 0.9942 - loss: 0.0198 - val_accuracy: 0.9816 - val_loss: 0.0557
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 120ms/step - accuracy: 0.9964 - loss: 0.0135 - val_accuracy: 0.9826 - val_loss: 0.0538
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.9977 - loss: 0.0087 - val_accuracy: 0.9823 - val_loss: 0.0587
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.9974 - loss: 0.0085 - val_accuracy: 0.9824 - val_loss: 0.0645
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 57s 122ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9823 - val_loss: 0.0699
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 108s 178ms/step - accuracy: 0.9981 - loss: 0.0068 - val_accuracy: 0.9850 - val_loss: 0.0605
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9819 - val_loss: 0.0797
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9783 - loss: 0.0959
# Test loss: 0.07966431975364685
# Test accuracy: 0.9818999767303467
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# Accuracy on test set: 0.9819
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9783 - loss: 0.0959
# loss= 0.07966431975364685
# accuracy= 0.9818999767303467

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(3,3), strides=(2,2), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.8555 - loss: 0.5649 - val_accuracy: 0.9670 - val_loss: 0.1136
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.9703 - loss: 0.1060 - val_accuracy: 0.9736 - val_loss: 0.0861
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9812 - loss: 0.0626 - val_accuracy: 0.9808 - val_loss: 0.0607
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9878 - loss: 0.0420 - val_accuracy: 0.9817 - val_loss: 0.0560
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - accuracy: 0.9919 - loss: 0.0307 - val_accuracy: 0.9817 - val_loss: 0.0582
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9931 - loss: 0.0238 - val_accuracy: 0.9836 - val_loss: 0.0495
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9948 - loss: 0.0184 - val_accuracy: 0.9837 - val_loss: 0.0550
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9966 - loss: 0.0132 - val_accuracy: 0.9846 - val_loss: 0.0514
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.9972 - loss: 0.0104 - val_accuracy: 0.9822 - val_loss: 0.0602
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9984 - loss: 0.0075 - val_accuracy: 0.9825 - val_loss: 0.0618
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9775 - loss: 0.0767
# Test loss: 0.06179925054311752
# Test accuracy: 0.9825000166893005
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Accuracy on test set: 0.9825
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9775 - loss: 0.0767
# loss= 0.06179925054311752
# accuracy= 0.9825000166893005

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(3,3), strides=(3,3), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8323 - loss: 0.6839 - val_accuracy: 0.9456 - val_loss: 0.1814
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9541 - loss: 0.1580 - val_accuracy: 0.9609 - val_loss: 0.1261
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9690 - loss: 0.1038 - val_accuracy: 0.9725 - val_loss: 0.0885
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9782 - loss: 0.0740 - val_accuracy: 0.9742 - val_loss: 0.0833
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9837 - loss: 0.0556 - val_accuracy: 0.9770 - val_loss: 0.0706
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9867 - loss: 0.0435 - val_accuracy: 0.9797 - val_loss: 0.0646
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9881 - loss: 0.0374 - val_accuracy: 0.9803 - val_loss: 0.0625
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9909 - loss: 0.0297 - val_accuracy: 0.9824 - val_loss: 0.0606
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9943 - loss: 0.0223 - val_accuracy: 0.9804 - val_loss: 0.0682
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9950 - loss: 0.0190 - val_accuracy: 0.9813 - val_loss: 0.0600
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9784 - loss: 0.0696
# Test loss: 0.060018669813871384
# Test accuracy: 0.9812999963760376
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy on test set: 0.9813
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9784 - loss: 0.0696
# loss= 0.060018669813871384
# accuracy= 0.9812999963760376

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(1,1), strides=(1,1), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 56s 113ms/step - accuracy: 0.8643 - loss: 0.5082 - val_accuracy: 0.9479 - val_loss: 0.1860
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 115ms/step - accuracy: 0.9532 - loss: 0.1627 - val_accuracy: 0.9610 - val_loss: 0.1297
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 112ms/step - accuracy: 0.9663 - loss: 0.1116 - val_accuracy: 0.9664 - val_loss: 0.1111
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 114ms/step - accuracy: 0.9768 - loss: 0.0771 - val_accuracy: 0.9696 - val_loss: 0.1009
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 111ms/step - accuracy: 0.9817 - loss: 0.0591 - val_accuracy: 0.9725 - val_loss: 0.0892
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 111ms/step - accuracy: 0.9852 - loss: 0.0470 - val_accuracy: 0.9742 - val_loss: 0.0920
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 110ms/step - accuracy: 0.9873 - loss: 0.0400 - val_accuracy: 0.9741 - val_loss: 0.0950
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 110ms/step - accuracy: 0.9904 - loss: 0.0306 - val_accuracy: 0.9739 - val_loss: 0.0923
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 51s 108ms/step - accuracy: 0.9905 - loss: 0.0280 - val_accuracy: 0.9768 - val_loss: 0.0844
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 110ms/step - accuracy: 0.9940 - loss: 0.0199 - val_accuracy: 0.9716 - val_loss: 0.1133
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9688 - loss: 0.1358
# Test loss: 0.11332099884748459
# Test accuracy: 0.9715999960899353
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# Accuracy on test set: 0.9716
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9688 - loss: 0.1358
# loss= 0.11332099884748459
# accuracy= 0.9715999960899353

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(10,10), strides=(10,10), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7334 - loss: 0.9776 - val_accuracy: 0.9188 - val_loss: 0.2787
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9214 - loss: 0.2715 - val_accuracy: 0.9363 - val_loss: 0.2189
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9404 - loss: 0.2060 - val_accuracy: 0.9514 - val_loss: 0.1652
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9504 - loss: 0.1736 - val_accuracy: 0.9534 - val_loss: 0.1516
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9572 - loss: 0.1477 - val_accuracy: 0.9567 - val_loss: 0.1454
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9610 - loss: 0.1317 - val_accuracy: 0.9633 - val_loss: 0.1265
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9648 - loss: 0.1206 - val_accuracy: 0.9651 - val_loss: 0.1148
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9669 - loss: 0.1110 - val_accuracy: 0.9642 - val_loss: 0.1214
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9692 - loss: 0.1043 - val_accuracy: 0.9679 - val_loss: 0.1116
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9717 - loss: 0.0964 - val_accuracy: 0.9682 - val_loss: 0.1050
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9649 - loss: 0.1202
# Test loss: 0.10503946244716644
# Test accuracy: 0.9682000279426575
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy on test set: 0.9682
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9649 - loss: 0.1202
# loss= 0.10503946244716644
# accuracy= 0.9682000279426575

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(5,5), strides=(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8045 - loss: 0.7860 - val_accuracy: 0.9518 - val_loss: 0.1637
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9544 - loss: 0.1541 - val_accuracy: 0.9661 - val_loss: 0.1068
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9686 - loss: 0.1058 - val_accuracy: 0.9723 - val_loss: 0.0894
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9749 - loss: 0.0844 - val_accuracy: 0.9762 - val_loss: 0.0790
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9796 - loss: 0.0694 - val_accuracy: 0.9767 - val_loss: 0.0695
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9820 - loss: 0.0590 - val_accuracy: 0.9764 - val_loss: 0.0718
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9850 - loss: 0.0505 - val_accuracy: 0.9808 - val_loss: 0.0614
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9870 - loss: 0.0436 - val_accuracy: 0.9824 - val_loss: 0.0550
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9882 - loss: 0.0394 - val_accuracy: 0.9819 - val_loss: 0.0551
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9901 - loss: 0.0338 - val_accuracy: 0.9819 - val_loss: 0.0567
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9785 - loss: 0.0673
# Test loss: 0.05668577924370766
# Test accuracy: 0.9818999767303467
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy on test set: 0.9819
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9785 - loss: 0.0673
# loss= 0.05668577924370766
# accuracy= 0.9818999767303467

# %%
# keras imports for the dataset and building our neural network
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.utils import to_categorical

# to calculate accuracy
from sklearn.metrics import accuracy_score

# loading the dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train and y_train are the training images and their labels, respectively, while X_test and y_test are the test images and labels.

# Reshapes the data so it has the shape (samples, height, width, channels).
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#Converts the data type of the image data to float32 for better precision during training.

# #Divides the pixel values by 255 to normalize the images.
#This scales the values to the range [0, 1], which makes the training more stable and faster.
X_train /= 255
X_test /= 255

# one-hot encoding using keras' numpy-related utilities
n_classes = 10
print("Shape before one-hot encoding: ", y_train.shape)
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
print("Shape after one-hot encoding: ", Y_train.shape)

#The labels (y_train, y_test) are converted to one-hot encoded format.

# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer

model.add(Conv2D(25, kernel_size=(7,7), strides=(7,7), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

# flatten output of conv
model.add(Flatten())

# hidden layer
model.add(Dense(100, activation='relu'))

# output layer
model.add(Dense(10, activation='softmax'))

# compiling the sequential model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# training the model for 10 epochs
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))

# Evaluating the model on the test set
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding back to class labels (argmax gives the index of the highest probability)
y_pred_classes = y_pred.argmax(axis=-1)

# Convert Y_test back to class labels (argmax gives the index of the highest probability)
y_test_classes = Y_test.argmax(axis=-1)

# Calculating accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("Accuracy on test set:", accuracy)

score = model.evaluate(X_test, Y_test, verbose=1)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# Shape before one-hot encoding:  (60000,)
# Shape after one-hot encoding:  (60000, 10)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.7599 - loss: 0.8517 - val_accuracy: 0.9432 - val_loss: 0.1871
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9470 - loss: 0.1841 - val_accuracy: 0.9616 - val_loss: 0.1238
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9631 - loss: 0.1250 - val_accuracy: 0.9673 - val_loss: 0.1051
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9713 - loss: 0.0977 - val_accuracy: 0.9704 - val_loss: 0.0961
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9746 - loss: 0.0839 - val_accuracy: 0.9752 - val_loss: 0.0755
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9784 - loss: 0.0695 - val_accuracy: 0.9779 - val_loss: 0.0715
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9820 - loss: 0.0593 - val_accuracy: 0.9786 - val_loss: 0.0672
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9831 - loss: 0.0557 - val_accuracy: 0.9788 - val_loss: 0.0646
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9842 - loss: 0.0512 - val_accuracy: 0.9795 - val_loss: 0.0666
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9865 - loss: 0.0436 - val_accuracy: 0.9807 - val_loss: 0.0603
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9773 - loss: 0.0701
# Test loss: 0.06034834682941437
# Test accuracy: 0.9807000160217285
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy on test set: 0.9807
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9773 - loss: 0.0701
# loss= 0.06034834682941437
# accuracy= 0.9807000160217285
