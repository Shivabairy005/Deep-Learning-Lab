# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivabairy005/Deep-Learning-Lab/blob/main/DL_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

x = torch.randn(100, 3)
y = torch.randn(100, 1)

class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)

    def forward(self, x):
        return self.linear(x)

model = SimpleNet()
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(100):
    y_pred = model(x)
    loss = loss_fn(y_pred, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")

print("\nTraining finished.")
print(f"Final loss: {loss.item():.4f}")
# Out:
# Epoch 10, Loss: 1.0835
# Epoch 20, Loss: 0.9948
# Epoch 30, Loss: 0.9568
# Epoch 40, Loss: 0.9452
# Epoch 50, Loss: 0.9429
# Epoch 60, Loss: 0.9424
# Epoch 70, Loss: 0.9424
# Epoch 80, Loss: 0.9423
# Epoch 90, Loss: 0.9422
# Epoch 100, Loss: 0.9422
#
# Training finished.
# Final loss: 0.9422

# %%
import tensorflow as tf

x = tf.random.normal((100, 3))
y = tf.random.normal((100, 1))

model = tf.keras.Sequential([
    tf.keras.Input(shape=(3,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer="adam", loss="mse")

model.fit(x, y, epochs=100, verbose=0)

print("Final loss:", model.evaluate(x, y, verbose=0))
# Out:
# Final loss: 2.005136013031006

# %%
import tensorflow as tf

x = tf.random.normal((100, 3))
y = tf.random.normal((100, 1))

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(3,))
])

model.compile(optimizer="adam", loss="mse")

model.fit(x, y, epochs=100, verbose=0)

print("Final loss:", model.evaluate(x, y, verbose=0))

# %%
import numpy as np

def sigmoid(n):
  return 1 / (1 + np.exp(-n))

class Neuron:
    def __init__(self, weights, bias):
        self.weights = np.array(weights)
        self.bias = bias

    def feedforward(self, inputs):
        total = np.dot(self.weights, inputs) + self.bias
        return sigmoid(total)

weights = np.array([0, 1])
bias = 4
n = Neuron(weights, bias)

inputs_to_neuron = np.array([2, 3])
print(n.feedforward(inputs_to_neuron))
# Out:
# 0.9990889488055994
